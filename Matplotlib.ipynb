# %% [markdown]
# <a href="https://colab.research.google.com/github/CarolineAndradeR/Data-Science/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# O **Matplotlib** permite uma grande flexibilidade para a criação de gráficos, permitindo uma vasta interpretação e entendimento dos dados.

# %%
# !pip install matplotlib

# %%
# %matplotlib inline garante que os dados sejam mostrados e incorporados dentro da própria ferramente, sem correr o risco de ser exibidos em uma janela pop-up.

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
arr = np.arange(12)
plt.plot(arr)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
arr = np.arange((30))
arr2= [number**2 for number in arr]
plt.plot(arr2)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
eixoX=np.linspace(0,2,100)
seno =np.sin(2*np.pi*eixoX)
plt.plot(eixoX,seno); plt.show();

# %%
# Alterando o modo de visualização dos dados no grafico.
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
eixoX=np.linspace(0,2,20)
seno =np.sin(2*np.pi*eixoX)
plt.title('Titulo do gráfico');
plt.xlabel('Valor eixo X');
plt.ylabel('Valor eixo Y');
plt.grid(True);
plt.plot(eixoX,seno,color='tab:red',linestyle='--',marker='s'); plt.show();
plt.plot(eixoX,seno,'m:',drawstyle='steps-post'); plt.show();
x = np.arange(seno.size)
plt.bar(x, seno);

# %%
# Subplot - permite mais de um plot na mesma figura.
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
eixoX=np.linspace(0,2,20)
seno =np.sin(2*np.pi*eixoX)
#Subplot 1 - Cor ou estilo ou marcador
plt.subplot(2,2,1)
plt.plot(eixoX,seno,'g'); #Apenas cor
#Subplot 2 - Cor + estilo
plt.subplot(2,2,2) #Nomear os parâmetros é opcional
plt.plot(eixoX,seno,'k-.');
#Subplot 3 - Cor + marcador
plt.subplot(2,2,3)
plt.plot(eixoX,seno,'y*');
#Subplot 4 - Cor + estilo + marcador
plt.subplot(2,2,4)
plt.plot(eixoX,seno,'r--o');

# %%
# Gráfico de histograma é muito parecido com o famoso gráfico de barras, porem a altura é proporcional á distribuição de frequência de um conjunto de dados.
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
Dados = np.random.randint(0,10,50)
plt.hist(Dados,bins=10, rwidth=0.9)
plt.show()

# %%
#Gráfico de dispersão permite a representação de medids de dispersão, de como uma variável se relaciona com outra, são relacionadas 2 variáveis.
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
X = np.random.normal(-1, 1, 1000)
Y = np.random.normal(-1, 1, 1000)
fig = plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.scatter(X, Y)
plt.subplot(1,2,2); plt.scatter(X, Y, alpha=0.25);plt.show();

# %%
# adaptação do código fonte: https://github.com/rougier/scientific-visualization-book/blob/master/code/ornaments/elegant-scatter.py
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["font.size"] = 10.0
plt.rcParams["font.serif"] = ["Source Serif Pro"]
plt.rcParams["font.sans-serif"] = ["Source Sans Pro"]
plt.rcParams["font.monospace"] = ["Source Code Pro"]
fig = plt.figure(figsize=(10, 10))
ax = plt.axes()
ax.set_xlabel("Altura (m)", weight="medium")
ax.set_ylabel("Peso (kg)", weight="medium")
ax.set_title(
    """Distribuição de peso e altura
""" """de acordo com sexo e idade (dados fake)""",
    family="serif",
)
n = 500
#np.random.seed(1)
X, Y = np.zeros(2 * n), np.zeros(2 * n)
S, C = np.zeros(2 * n), np.zeros(2 * n)
X[:n] = np.random.normal(1.60, 0.1, n)
Y[:n] = np.random.normal(50, 10, n)
S[:n] = np.random.uniform(25, 50, n)
C[:n] = 0
X[n:] = np.random.normal(1.75, 0.1, n)
Y[n:] = np.random.normal(75, 10, n)
S[n:] = np.random.uniform(25, 50, n)
C[n:] = 1
cmap = plt.get_cmap("RdYlBu")
scatter = plt.scatter(X, Y, s=S, edgecolor="black", linewidth=0.75, zorder=-20)
scatter = plt.scatter(X, Y, s=S, edgecolor="None", facecolor="white", zorder=-10)
scatter = plt.scatter(X, Y, c=C, s=S, cmap=cmap, edgecolor="None", alpha=0.25)
handles, labels = scatter.legend_elements(
    num=3,
    prop="sizes",
    alpha=1,
    markeredgewidth=0.8,
    markeredgecolor="black",
    markerfacecolor="None",
)
legend = plt.legend(
    handles,
    labels,
    title=" Idade",
    loc=(0.6, 0.05),
    handletextpad=0.1,
    labelspacing=0.25,
    facecolor="None",
    edgecolor="None",
)
legend.get_children()[0].align = "left"
legend.get_title().set_fontweight("medium")
ax.add_artist(legend)
handles, labels = scatter.legend_elements(markeredgewidth=0.0, markeredgecolor="black")
labels = ["Feminino", "Masculino"]
legend = plt.legend(
    handles,
    labels,
    title=" Sexo",
    loc=(0.75, 0.05),
    handletextpad=0.1,
    labelspacing=0.25,
    facecolor="None",
    edgecolor="None",
)
legend.get_children()[0].align = "left"
legend.get_title().set_fontweight("medium")
plt.scatter(X, [19] * len(X), marker="|", color=cmap(C), linewidth=0.5, alpha=0.25)
plt.scatter([1.3] * len(X), Y, marker="_", color=cmap(C), linewidth=0.5, alpha=0.25)
# Out:
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Source Sans Pro
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Source Sans Pro
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Source Sans Pro
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Source Sans Pro
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Source Sans Pro
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Source Sans Pro
# ...

# %%
# Boxplot - Exibe a distribuição de conjuntos de dados quantitativos em quartis, de uma forma que facilita a comparação entre variáveis ou entre níveis de uma variável categórica.
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
Z = np.random.normal(0, 1, (100,5))
plt.boxplot(Z)
plt.show()
